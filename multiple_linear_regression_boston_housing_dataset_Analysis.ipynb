# %% [markdown]
# # Date : 19 - 06 -2023

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import pandas as pd

# %%
bd=pd.read_csv('boston.csv')
bd.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
bd.isnull().any()
# Out:
# crim       False
# zn         False
# indus      False
# chas       False
# nox        False
# rm         False
# age        False
# dis        False
# rad        False
# tax        False
# ptratio    False
# b          False
# lstat      False
# medv       False
# dtype: bool

# %%
# crim plotting:
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(20,8))
ax[0].scatter(bd['crim'],bd['medv'],color='purple',marker='^')
ax[0].set_xlabel("Plotting of crime with MEDV value")
ax[0].set_ylabel("Plotting of price frequency")
ax[0].set_title("Scattering plotting of crime with price")

#Histogram plotting of crime
ax[1].hist(bd['crim'],color='skyblue')
ax[1].grid(ls='--')
ax[1].set_xlabel('Crime')
ax[1].set_ylabel('Price frequency')
ax[1].set_title("histogram plotting")
plt.show()

# %%
# crim plotting:
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(20,8))
ax[0].scatter(bd['crim'],bd['medv'],color='purple',marker='^')
ax[0].set_xlabel("Plotting of crime with MEDV value")
ax[0].set_ylabel("Plotting of price frequency")
ax[0].set_title("Scattering plotting of crime with price")
ax[0].axis([0,10,0,60])

#Histogram plotting of crime
ax[1].hist(bd['crim'],color='skyblue',bins=100)
ax[1].grid(ls='--')
ax[1].set_xlabel('Crime')
ax[1].set_ylabel('Price frequency')
ax[1].set_title("histogram plotting")
ax[1].axis([0,10,0,350])
plt.show()

# %%
# zn plotting
#plotting a bar graph for the resdential zoned area
bd['zn'].value_counts()
# Out:
# 0.0      372
# 20.0      21
# 80.0      15
# 22.0      10
# 12.5      10
# 25.0      10
# 40.0       7
# 45.0       6
# 30.0       6
# 90.0       5
# 95.0       4
# 60.0       4
# 21.0       4
# 33.0       4
# 55.0       3
# 70.0       3
# 34.0       3
# 52.5       3
# 35.0       3
# 28.0       3
# 75.0       3
# 82.5       2
# 85.0       2
# 17.5       1
# 100.0      1
# 18.0       1
# Name: zn, dtype: int64

# %%
values=['zero','non-zero']
frequencies=[bd[bd['zn']==0]['medv'].mean(),bd[bd['zn']!=0]['medv'].mean()]

# %%
print(frequencies)
# Out:
# [20.473387096774193, 28.25]

# %%
sns.barplot(x=values,y=frequencies)
plt.xlabel("zn")
plt.ylabel("medv")
plt.title("Bar Graph analysis")
plt.show()

# %%
# industrial area analysis'
# scatter indus value correlation with target MEDV

plt.scatter(bd['indus'],bd['medv'],marker='<',color='orange')
plt.xlabel("indus")
plt.ylabel('Price')
plt.title('This is industrial zone plotting...!')
plt.show()

# %%
bd['chas'].value_counts()
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %%
# chas river dammy
value=['zero','one']
frequencies=[bd[bd['chas']==0].shape[0],bd[bd['chas']==1].shape[1]]
print(frequencies)
# Out:
# [471, 14]

# %%
#plotting of charis river dummy
fig=plt.figure(figsize=(20,8))
fig.add_subplot(1,2,1)
plt.pie(frequencies,labels=value,colors=['orange','red'],explode=(0.1,0)
        ,counterclock=False,autopct="%.2f%%",shadow=True)
plt.title('Pie chart Analysis')

fig.add_subplot(1,2,2)
sns.barplot(x=value,y=frequencies)
plt.xlabel("Chas")
plt.ylabel("Price")
plt.title("Bar Graph Analysis")
plt.show()

# %% [markdown]
# # Date : 20-06-2023

# %%
bd.keys()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
bd.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
plt.scatter(bd['nox'],bd['medv'],marker='1',color='gray')
plt.xlabel('nitric oxide')
plt.ylabel('Price')
plt.title("Scattering nox and Price")
plt.grid(ls='--')
plt.show()

# %%
fig=plt.figure(figsize=(20,8))
fig.add_subplot(1,2,1)
plt.scatter(bd['rm'],bd['medv'],marker='+',color='olive')
plt.xlabel("Rooms")
plt.ylabel("Price")
plt.title('Room Analysis')
plt.grid(ls='--')

fig.add_subplot(1,2,2)
sns.boxplot(y=bd['rm'],color='yellow')
plt.title("Box plotting of Rooms")
plt.show()

# %%
plt.scatter(bd['age'],bd['medv'],color='lightblue')
plt.ylabel('Age')
plt.ylabel("Price")
plt.title("Scattering Age with price")
plt.show()

# %%
plt.scatter(bd['dis'],bd['medv'],color='pink',marker='2')
plt.ylabel('Dis')
plt.ylabel("Price")
plt.title("Scattering Dis with price")
plt.show()

# %%
plt.scatter(bd['rad'],bd['medv'],color='red',marker='2')
plt.ylabel('Rad')
plt.ylabel("Price")
plt.title("Scattering Rad with price")
plt.show()

# %%
plt.scatter(bd['tax'],bd['medv'],color='brown',marker='.')
plt.ylabel('Tax')
plt.ylabel("Price")
plt.title("Scattering Tax with price")
plt.show()

# %%
plt.scatter(bd['ptratio'],bd['medv'],color='black',marker='*')
plt.ylabel('PTratio')
plt.ylabel("Price")
plt.title("Scattering PTratio with price")
plt.show()

# %%
# Scattering b and y
fig=plt.figure(figsize=(20,8))
fig.add_subplot(1,2,1)
plt.scatter(bd['b'],bd['medv'],color='purple',marker='^')
plt.xlabel('b')
plt.ylabel('medv')
plt.title('scattering B with price')

fig.add_subplot(1,2,2)
sns.boxplot(y=bd['b'],color='orange')
plt.title("Box plot Analysis")
plt.xlabel('b')
plt.ylabel('medv')
plt.show()

# %%
#lstat
#scattering lstat and medv 
fig=plt.figure(figsize=(20,8))
fig.add_subplot(1,2,1)
plt.scatter(bd['lstat'],bd['medv'],color='skyblue',marker='^')
plt.xlabel('lstat')
plt.ylabel('medv')
plt.title('scattering B with price')

fig.add_subplot(1,2,2)
sns.boxplot(y=bd['lstat'],color='lightblue')
plt.title("Box plot Analysis")
plt.xlabel('lstat')
plt.ylabel('medv')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
rows=2
cols=7
fig,ax=plt.subplots(nrows=rows,ncols=cols,figsize=(16,4))
col=bd.columns
index=0
for i in range(rows):
    for j in range(cols):
        sns.distplot(bd[col[index]],ax=ax[i][j],color='khaki')
        index=index+1
plt.tight_layout()

# %%
for k,v in bd.items():
    q1=v.quantile(0.25)
    q3=v.quantile(0.75)
    irq=q3-q1
    v_cal=v[(v<q1-1.5*irq) | (v>q3+1.5*irq)]
    perc=np.shape(v_cal)[0]*100.0/np.shape(bd)[0]
    print("Column %s outliers = %.2f%%"%(k,perc))
# Out:
# Column crim outliers = 13.04%
# Column zn outliers = 13.44%
# Column indus outliers = 0.00%
# Column chas outliers = 6.92%
# Column nox outliers = 0.00%
# Column rm outliers = 5.93%
# Column age outliers = 0.00%
# Column dis outliers = 0.99%
# Column rad outliers = 0.00%
# Column tax outliers = 0.00%
# Column ptratio outliers = 2.96%
# Column b outliers = 15.22%
# Column lstat outliers = 1.38%
# Column medv outliers = 7.91%

# %%
cormat=bd.corr()
cormat
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
fig=plt.figure(figsize=(12,8))
fig.add_subplot(1,1,1)
sns.heatmap(bd.corr(),annot=True)
plt.show()

# %% [markdown]
# # Threshold

# %%
def getcorrelatedfeatures(corrdata,threshold):
    feature=[]
    value=[]
    for i, index in enumerate(corrdata.index):
        if abs(corrdata[index])>threshold:
            feature.append(index)
            value.append(corrdata[index])
    df=pd.DataFrame(data=value,index=feature,columns=['corr_value'])
    return df

# %%
threshold=0.50
corr_value=getcorrelatedfeatures(cormat['medv'],threshold)
corr_value
# Out:
#          corr_value
# rm         0.695360
# ptratio   -0.507787
# lstat     -0.737663
# medv       1.000000

# %%
correlated_data=bd[corr_value.index]
correlated_data.head()
# Out:
#       rm  ptratio  lstat  medv
# 0  6.575     15.3   4.98  24.0
# 1  6.421     17.8   9.14  21.6
# 2  7.185     17.8   4.03  34.7
# 3  6.998     18.7   2.94  33.4
# 4  7.147     18.7   5.33  36.2

# %%
sns.pairplot(correlated_data)
plt.tight_layout()

# %%
sns.distplot(correlated_data)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.heatmap(correlated_data.corr(),annot=True,annot_kws={'size':10})
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
x=correlated_data.drop(labels=['medv'],axis=1)
y=correlated_data['medv']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((404, 3), (102, 3))

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
df=pd.DataFrame(data=[y_pred,Y_test])
df.T.head()
# Out:
#            0     1
# 0  26.718396  23.6
# 1  30.663291  32.4
# 2  16.426377  13.6
# 3  24.728708  22.8
# 4  18.342368  16.1

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
score=r2_score(Y_test,y_pred)
mae=mean_absolute_error(Y_test,y_pred)
mse=mean_squared_error(Y_test,y_pred)
print("The R2 score is ",score)
print("The mean absoluet error is ",mae)
print("The mean squared error is ",mse)
# Out:
# The R2 score is  0.6302528487272827
# The mean absoluet error is  3.3325380783240965
# The mean squared error is  27.114957415580577

# %%
import pickle

# %%
with open('boston_model','wb') as f:
    pickle.dump(model,f)

# %%
from flask import Flask

# %%
from flask import Flask
from flask import request
from flask import render_template
import joblib
app = Flask(__name__)

model = joblib.load('boston_model')
@app.route('/')
def hello(name=None):
    return render_template('index.html',name=name)


@app.route('/results', methods =["GET", "POST"])
def get_value():
    if request.method == "POST":
        rm = float(request.form.get('rm'))
        pt = float(request.form.get('pt'))
        lstat = float(request.form.get('lstat'))
        predict_value = model.predict([[rm,pt,lstat]])
        
    return render_template('results.html',prediction=predict_value)

# %%
model
# Out:
# LinearRegression()

# %%
if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
